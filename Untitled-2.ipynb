# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (assuming athlete_events is a DataFrame)
athlete_events = pd.DataFrame({
    'Year': [2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016],
    'Sport': ["Athletics", "Badminton", "Boxing", "Cycling", "Gymnastics", "Swimming", "Athletics", "Cycling"]
})

selected_sports = ["Athletics", "Badminton", "Boxing", "Cycling", "Gymnastics", "Swimming"]

my_data = athlete_events[(athlete_events['Year'] == 2016) & (athlete_events['Sport'].isin(selected_sports))]

sport_counts = my_data['Sport'].value_counts()
total_counts = sport_counts.sum()

plt.figure(figsize=(8, 8))
plt.pie(sport_counts, labels=sport_counts.index, autopct=lambda p: '{:.0f}%'.format(p * total_counts / 100))
plt.title("Pie chart of six types of sports in 2016")
plt.show()

# %%
athlete_events
# Out:
#    Year       Sport
# 0  2016   Athletics
# 1  2016   Badminton
# 2  2016      Boxing
# 3  2016     Cycling
# 4  2016  Gymnastics
# 5  2016    Swimming
# 6  2016   Athletics
# 7  2016     Cycling

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (assuming athlete_events is a DataFrame)
athlete_event = pd.DataFrame({
    'Year': [2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016],
    'Sport': ["Athletics", "Badminton", "Boxing", "Cycling", "Gymnastics", "Swimming", "Athletics", "Cycling"]
})

selected_sports = ["Athletics", "Badminton", "Boxing", "Cycling", "Gymnastics", "Swimming"]

my_data = athlete_events[(athlete_events['Year'] == 2016) & (athlete_events['Sport'].isin(selected_sports))]

sport_counts = my_data['Sport'].value_counts()
total_counts = sport_counts.sum()

plt.figure(figsize=(8, 8))
plt.pie(sport_counts, labels=sport_counts.index, autopct=lambda p: '{:.0f}%'.format(p * total_counts / 100))
plt.title("Pie chart of six types of sports in 2016")
plt.show()

# %%
athlete_events
# Out:
#    Year       Sport
# 0  2016   Athletics
# 1  2016   Badminton
# 2  2016      Boxing
# 3  2016     Cycling
# 4  2016  Gymnastics
# 5  2016    Swimming
# 6  2016   Athletics
# 7  2016     Cycling

# %%
import pandas as pd
my_data = pd.read_csv("athlete_events.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 my_data = pd.read_csv("athlete_events.csv")
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Read data from Excel file into a pandas DataFrame
athlete_events = pd.read_excel('athlete_events.xlsx')

# Now you can work with the DataFrame 'df'
print(athlete_events.head())  # Display the first few rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pandas as pd
#       3 # Read data from Excel file into a pandas DataFrame
# ----> 4 athlete_events = pd.read_excel('athlete_events.xlsx')
#       6 # Now you can work with the DataFrame 'df'
#       7 print(athlete_events.head())  # Display the first few rows of the DataFrame
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# ...

# %%
athlete_events.to_csv
# Out:
# <bound method NDFrame.to_csv of    Year       Sport
# 0  2016   Athletics
# 1  2016   Badminton
# 2  2016      Boxing
# 3  2016     Cycling
# 4  2016  Gymnastics
# 5  2016    Swimming
# 6  2016   Athletics
# 7  2016     Cycling>

# %%
import pandas as pd

# Read data from Excel file into a pandas DataFrame
df = pd.read_excel('athlete_events.csv')

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 import pandas as pd
#       3 # Read data from Excel file into a pandas DataFrame
# ----> 4 df = pd.read_excel('athlete_events.csv')
#       6 # Now you can work with the DataFrame 'df'
#       7 print(df.head())  # Display the first few rows of the DataFrame
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...

# %%
import pandas as pd

# Replace 'path/to/athlete_events.csv' with the actual absolute path to your file
df = pd.read_excel('path/to/athlete_events.csv')

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 import pandas as pd
#       3 # Replace 'path/to/athlete_events.csv' with the actual absolute path to your file
# ----> 4 df = pd.read_excel('path/to/athlete_events.csv')
#       6 # Now you can work with the DataFrame 'df'
#       7 print(df.head())  # Display the first few rows of the DataFrame
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# ...

# %%
import pandas as pd

# Replace 'C:/Users/YourUsername/Documents/athlete_events.csv' with the actual absolute path to your file
df = pd.read_excel('C:/Users/USER/Desktop/athlete_events.csv')

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 import pandas as pd
#       3 # Replace 'C:/Users/YourUsername/Documents/athlete_events.csv' with the actual absolute path to your file
# ----> 4 df = pd.read_excel('C:/Users/USER/Desktop/athlete_events.csv')
#       6 # Now you can work with the DataFrame 'df'
#       7 print(df.head())  # Display the first few rows of the DataFrame
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
# ...

# %%
import pandas as pd

# Replace 'C:/Users/USER/Desktop/athlete_events.csv' with the actual absolute path to your file
df = pd.read_excel('C:/Users/USER/Desktop/athlete_events.csv', engine='openpyxl')

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Replace 'C:/Users/YourUsername/Documents/athlete_events.csv' with the actual absolute path to your file
df = pd.read_excel('C:\Users\USER\Desktop\athlete_events.csv')

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
# Out:
#   Cell In[13], line 4
#     df = pd.read_excel('C:\Users\USER\Desktop\athlete_events.csv')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

# Replace 'C:/Users/YourUsername/Documents/athlete_events.csv' with the actual absolute path to your file
df = pd.read_excel(r'C:\Users\USER\Desktop\athlete_events.csv')

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       1 import pandas as pd
#       3 # Replace 'C:/Users/YourUsername/Documents/athlete_events.csv' with the actual absolute path to your file
# ----> 4 df = pd.read_excel(r'C:\Users\USER\Desktop\athlete_events.csv')
#       6 # Now you can work with the DataFrame 'df'
#       7 print(df.head())  # Display the first few rows of the DataFrame
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
# ...

# %%
import pandas as pd

# Replace 'C:/Users/YourUsername/Documents/athlete_events.csv' with the actual absolute path to your file
df = pd.read_excel('C:\\Users\\USER\\Desktop\\athlete_events.csv')

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       1 import pandas as pd
#       3 # Replace 'C:/Users/YourUsername/Documents/athlete_events.csv' with the actual absolute path to your file
# ----> 4 df = pd.read_excel('C:\\Users\\USER\\Desktop\\athlete_events.csv')
#       6 # Now you can work with the DataFrame 'df'
#       7 print(df.head())  # Display the first few rows of the DataFrame
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
# ...

# %%
import pandas as pd

# Replace 'C:/Users/USER/Desktop/athlete_events.csv' with the actual absolute path to your file
df = pd.read_csv(r'C:\Users\USER\Desktop\athlete_events.csv')

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
import pandas as pd

# Replace 'C:/Users/USER/Desktop/athlete_events.csv' with the actual absolute path to your file
athlete_events = pd.read_csv(r'C:\Users\USER\Desktop\athlete_events.csv')

# Now you can work with the DataFrame 'athlete_events'
print(athlete_events.head())  # Display the first few rows of the DataFrame
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming athlete_events is a DataFrame containing the data
# Teams and unique_colors lists are defined as in the R code

Year2014 = athlete_events[athlete_events['Year'] == 2014]

Teams = ["United States", "Russia", "Norway", "Germany", "Canada"]

m_data = Year2014[Year2014['Team'].isin(Teams)]

m_data_unique = m_data.drop_duplicates(subset='Name')

team_counts = m_data_unique['Team'].value_counts().reset_index()
team_counts.columns = ['Team', 'n']
team_counts = team_counts.sort_values(by='n', ascending=False)

m_data_unique['Team'] = pd.Categorical(m_data_unique['Team'], categories=team_counts['Team'], ordered=True)

unique_colors = ["#FF5733", "#FFBD33", "#33FF57", "#33FFBD", "#5733FF"]

plt.figure(figsize=(10, 6))
plt.bar(m_data_unique['Team'], m_data_unique.groupby('Team').size(), color=unique_colors, edgecolor='black', alpha=0.8)
plt.xlabel('Countries')
plt.ylabel('Athletes')
plt.title('The number of athletes participating from five countries in the 2014 Winter Olympics')
plt.xticks(rotation=90)
plt.gca().set_facecolor('white')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\2081249341.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_data_unique['Team'] = pd.Categorical(m_data_unique['Team'], categories=team_counts['Team'], ordered=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\2081249341.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   plt.bar(m_data_unique['Team'], m_data_unique.groupby('Team').size(), color=unique_colors, edgecolor='black', alpha=0.8)
# ---------------------------------------------------------------------------
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming athlete_events is a DataFrame containing the data
# circles DataFrame and total_athletes variable are defined as in the R code

b_data = athlete_events[athlete_events['Sport'].isin(["Boxing", "Football", "Judo", "Swimming", "Taekwondo"])]

athlete_counts = b_data['Sport'].value_counts().reset_index()
athlete_counts.columns = ['Sport', 'n']
athlete_counts = athlete_counts.sort_values(by='n', ascending=False)

total_athletes = athlete_counts['n'].sum()

circles = pd.DataFrame({
    'xmin': [-1, -0.5],
    'xmax': [1, 0.5],
    'ymin': [-1, -0.5],
    'ymax': [1, 0.5]
})

plt.figure(figsize=(8, 8))
plt.gca().add_patch(plt.Rectangle((-1, -1), 2, 2, color='gray'))
plt.bar("", b_data['Sport'].value_counts(), color='gray')
for i, row in athlete_counts.iterrows():
    if row['Sport'] != "Taekwondo":
        plt.text(0, row['n']/2, str(row['n']), ha='center', va='center', fontsize=10)
    else:
        plt.text(0, row['n']/2 + 50, str(row['n']), ha='center', va='center', fontsize=10)
plt.axis('equal')
plt.gca().set_facecolor('none')
plt.title('The number of athletes participating in the Olympic during 120 Years')
plt.xl
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[20], line 24
#      22 plt.figure(figsize=(8, 8))
#      23 plt.gca().add_patch(plt.Rectangle((-1, -1), 2, 2, color='gray'))
# ---> 24 plt.bar("", b_data['Sport'].value_counts(), color='gray')
#      25 for i, row in athlete_counts.iterrows():
#      26     if row['Sport'] != "Taekwondo":
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming athlete_events is a DataFrame containing the data
# 'Boxing', 'Football', 'Judo', 'Swimming', and 'Taekwondo' are stored in the list 'selected_sports'

b_data = athlete_events[athlete_events['Sport'].isin(selected_sports)]

athlete_counts = b_data['Sport'].value_counts().reset_index()
athlete_counts.columns = ['Sport', 'n']
athlete_counts = athlete_counts.sort_values(by='n', ascending=False)

total_athletes = athlete_counts['n'].sum()

circles = pd.DataFrame({
    'xmin': [-1, -0.5],
    'xmax': [1, 0.5],
    'ymin': [-1, -0.5],
    'ymax': [1, 0.5]
})

plt.figure(figsize=(8, 8))
plt.gca().add_patch(plt.Rectangle((-1, -1), 2, 2, color='gray'))
plt.bar("", b_data['Sport'].value_counts(), color='gray')
for i, row in athlete_counts.iterrows():
    if row['Sport'] != "Taekwondo":
        plt.text(0, row['n']/2, str(row['n']), ha='center', va='center', fontsize=10)
    else:
        plt.text(0, row['n']/2 + 50, str(row['n']), ha='center', va='center', fontsize=10)
plt.axis('equal')
plt.gca().set_facecolor('none')
plt.title('The number of athletes participating in the Olympic during 120 Years')
plt.xlabel('Sport')
plt.legend(['Sport'])
plt.figtext(0.5, 0.01, f'Total Athletes: {total_athletes}', ha='center', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[21], line 24
#      22 plt.figure(figsize=(8, 8))
#      23 plt.gca().add_patch(plt.Rectangle((-1, -1), 2, 2, color='gray'))
# ---> 24 plt.bar("", b_data['Sport'].value_counts(), color='gray')
#      25 for i, row in athlete_counts.iterrows():
#      26     if row['Sport'] != "Taekwondo":
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming athlete_events is a DataFrame containing the data
# 'Boxing', 'Football', 'Judo', 'Swimming', and 'Taekwondo' are stored in the list 'selected_sports'

b_data = athlete_events[athlete_events['Sport'].isin(selected_sports)]

athlete_counts = b_data['Sport'].value_counts().reset_index()
athlete_counts.columns = ['Sport', 'n']
athlete_counts = athlete_counts.sort_values(by='n', ascending=False)

total_athletes = athlete_counts['n'].sum()

plt.figure(figsize=(8, 8))
plt.pie(athlete_counts['n'], labels=athlete_counts['Sport'], autopct='%1.1f%%', startangle=90, colors=plt.cm.tab10.colors)
# Draw a white circle at the center to create a doughnut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')  
plt.title('The number of athletes participating in the Olympic during 120 Years')
plt.figtext(0.5, 0.01, f'Total Athletes: {total_athletes}', ha='center', fontsize=12)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming athlete_events is a DataFrame containing the data

filtered_dat = athlete_events[(athlete_events['Year'] >= 1990) & (athlete_events['Year'] <= 2016)]

summary_dat = filtered_dat.groupby(['Year', 'Season']).size().reset_index(name='total_athletes')

plt.figure(figsize=(10, 6))
for season, color in zip(summary_dat['Season'].unique(), ['darkorange', 'steelblue']):
    season_data = summary_dat[summary_dat['Season'] == season]
    plt.plot(season_data['Year'], season_data['total_athletes'], marker='o', linestyle='-', color=color, label=season)
    for year, athletes in zip(season_data['Year'], season_data['total_athletes']):
        plt.text(year, athletes, f'{athletes}', ha='center', va='bottom', fontsize=10)

plt.xlabel('Year', fontsize=16, labelpad=16)
plt.ylabel('Total Athletes', fontsize=16, labelpad=16)
plt.title('Total Athletes in Summer and Winter Olympics (1990 - 2016)', fontsize=18, pad=20)
plt.xticks(range(1990, 2017, 2))
plt.legend()
plt.grid(True)
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries

east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map
ax = east_asian_map_with_athletes.plot(column='athlete_count', cmap='viridis', figsize=(10, 10), legend=True)
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 import geopandas as gpd
#       2 import matplotlib.pyplot as plt
#       3 import contextily as ctx
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
pip install geopandas
# Out:
# ...
#      ---------------------------------------- 0.0/51.5 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/51.5 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/51.5 kB ? eta -:--:--
#      -------------------------------------- 51.5/51.5 kB 378.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------- -------------------------------- 0.2/1.1 MB 6.3 MB/s eta 0:00:01
#    -------- ------------------------------- 0.2/1.1 MB 3.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.3/1.1 MB 2.5 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.1 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  1.1/1.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 3.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries

east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map
ax = east_asian_map_with_athletes.plot(column='athlete_count', cmap='viridis', figsize=(10, 10), legend=True)
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 3
#       1 import geopandas as gpd
#       2 import matplotlib.pyplot as plt
# ----> 3 import contextily as ctx
#       5 # Assuming athlete_events is a DataFrame containing the data
#       6 # east_asian_countries list contains the East Asian countries
#       8 east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
#       9                         "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
#      10                         "Philippines", "Indonesia", "Timor-Leste"]
#
# ModuleNotFoundError: No module named 'contextily'

# %%
pip install contextily
# Out:
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------- ----------------- 71.7/125.4 kB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 71.7/125.4 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    -------------- ------------------------- 112.6/301.8 kB 2.2 MB/s eta 0:00:01
#    --------------------------- ------------ 204.8/301.8 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  297.0/301.8 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 301.8/301.8 kB 2.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/24.3 MB ? eta -:--:--
#    ---------------------------------------- 0.2/24.3 MB 5.0 MB/s eta 0:00:05
#    ---------------------------------------- 0.3/24.3 MB 3.5 MB/s eta 0:00:07
# ...

# %%
|import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries

east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map
ax = east_asian_map_with_athletes.plot(column='athlete_count', cmap='viridis', figsize=(10, 10), legend=True)
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()
plt.show()
# Out:
#   Cell In[28], line 1
#     |import geopandas as gpd
#     ^
# SyntaxError: invalid syntax

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Your code continues here...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries

east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau", "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei", "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & (athlete_events['Year'].between(1990, 2016))]\
.groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map
ax = east_asian_map_with_athletes.plot(column='athlete_count', cmap='viridis', figsize=(10, 10), legend=True)
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\1466242669.py:11: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 28
#      26 # Plot the map
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map
ax = east_asian_map_with_athletes.plot(column='athlete_count', cmap='viridis', figsize=(10, 10), legend=True)
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\3841491879.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 30
#      28 # Plot the map
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='viridis', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y), fontsize=8, ha='center')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\1284336451.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 39
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='viridis', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y), fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\4057914387.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 39
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='viridis', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y), fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\4057914387.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 39
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import random

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
num_countries = len(east_asian_countries)
palette_colors = [plt.cm.tab10(i/float(num_countries)) for i in range(num_countries)]

# Plot the map
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='viridis', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations with different colors
for idx, row in east_asian_map_with_athletes.iterrows():
    color = random.choice(palette_colors)
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y), fontsize=8, ha='center', color=color)

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\3458740796.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 42
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import random

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
num_countries = len(east_asian_countries)
palette_colors = [plt.cm.tab10(i/float(num_countries)) for i in range(num_countries)]

# Plot the map with a different colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='YlOrRd', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations with different colors
for idx, row in east_asian_map_with_athletes.iterrows():
    color = random.choice(palette_colors)
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y), fontsize=8, ha='center', color=color)

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\553291992.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 42
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import random

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
num_countries = len(east_asian_countries)
palette_colors = [plt.cm.tab20(i/float(num_countries)) for i in range(num_countries)]

# Plot the map with a different colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='BuPu', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations with different
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\1939325125.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import random

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
num_countries = len(east_asian_countries)
palette_colors = [plt.cm.tab20b(i/float(num_countries)) for i in range(num_countries)]

# Plot the map with a different colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='Oranges', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations with different colors
for idx, row in east_asian_map_with_athletes.iterrows():
    color = random.choice(palette_colors)
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y), fontsize=8, ha='center', color=color)

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\1333648914.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 42
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import random

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define palette colors
num_countries = len(east_asian_countries)
palette_colors = [plt.cm.Blues(i/float(num_countries)) for i in range(num_countries)]

# Plot the map with a different colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='Blues', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations with different colors
for idx, row in east_asian_map_with_athletes.iterrows():
    color = random.choice(palette_colors)
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y), fontsize=8, ha='center', color=color)

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\2240101169.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 42
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import random

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the specified colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map with the specified colors
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='Blues', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations with the specified colors
for idx, row in east_asian_map_with_athletes.iterrows():
    color = random.choice(palette_colors)
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y), fontsize=8, ha='center', color=color)

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\1175464180.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 41
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the specified colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map with the specified colors
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='Blues', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\2339673429.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 40
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the specified colors (darker shades of blue)
palette_colors = ["#005A8C", "#004E7A", "#00426A", "#003656", "#00243E"]

# Plot the map with the specified colors
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='Blues', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\986505951.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 40
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the specified colors (darker shades of blue)
palette_colors = ["#004C6D", "#004359", "#003D4C", "#00353B", "#002D2D"]

# Plot the map with the specified colors
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='Blues', legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\1597329422.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 40
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from matplotlib.colors import Normalize
from matplotlib.colors import LinearSegmentedColormap

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the colormap with the specified color and range
colors = ['#FFFFFF', '#4287f5']
cmap = LinearSegmentedColormap.from_list('custom', colors, N=750)

# Plot the map with the specified colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap=cmap, legend=True,
                                  norm=Normalize(vmin=0, vmax=750))
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\3998778232.py:14: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 44
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the specified colors
palette_colors = ["#66CCFF", "#0099FF", "#0066FF", "#0033CC", "#000099"]

# Plot the map with the specified colors
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap='Blues', legend=True, 
                                  legend_kwds={'label': 'Number of Athletes', 'orientation': 'horizontal'})
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\2991033279.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 41
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from matplotlib.colors import LinearSegmentedColormap

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the custom colormap
colors = ['#FFFFFF', '#66CCFF']
cmap = LinearSegmentedColormap.from_list('custom', colors, N=500)

# Plot the map with the custom colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap=cmap, legend=True)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\3974055857.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 42
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from matplotlib.colors import LinearSegmentedColormap

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the custom colormap
colors = ['#FFFFFF', '#66CCFF', '#0099FF', '#0066FF', '#0033CC', '#000099']
boundaries = [0, 500, 1000, 1500, 2000, 2500]
cmap = LinearSegmentedColormap.from_list('custom', colors, N=2500)

# Plot the map with the custom colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap=cmap, legend=True,
                                  legend_kwds={'label': 'Number of Athletes', 'orientation': 'horizontal'},
                                  vmin=0, vmax=2500)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\4210346306.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 45
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from matplotlib.colors import LinearSegmentedColormap

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the custom colormap with darker colors
colors = ['#FFFFFF', '#4267B2', '#254B77', '#17325E', '#0D1E44', '#000099']
boundaries = [0, 500, 1000, 1500, 2000, 2500]
cmap = LinearSegmentedColormap.from_list('custom', colors, N=2500)

# Plot the map with the custom colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap=cmap, legend=True,
                                  legend_kwds={'label': 'Number of Athletes', 'orientation': 'horizontal'},
                                  vmin=0, vmax=2500)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\3858572094.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 45
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from matplotlib.colors import LinearSegmentedColormap

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the custom colormap with the specified colors
colors = ['#FFFFFF', '#00CCFF', '#0099FF', '#0066FF', '#0033CC', '#000099']
boundaries = [0, 500, 1000, 1500, 2000, 2500]
cmap = LinearSegmentedColormap.from_list('custom', colors, N=2500)

# Plot the map with the custom colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap=cmap, legend=True,
                                  legend_kwds={'label': 'Number of Athletes', 'orientation': 'horizontal'},
                                  vmin=0, vmax=2500)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\4171959622.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 45
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from matplotlib.colors import LinearSegmentedColormap

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the custom colormap with the specified colors
colors = ['#FFFFFF', '#00CCFF', '#0099FF', '#0066FF', '#0033CC', '#000099']
boundaries = [0, 500, 1000, 1500, 2000, 2500]
cmap = LinearSegmentedColormap.from_list('custom', colors, N=2500)

# Plot the map with the custom colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap=cmap, legend=True,
                                  legend_kwds={'label': 'Number of Athletes', 'orientation': 'horizontal'},
                                  vmin=0, vmax=2500)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\4171959622.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 45
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from matplotlib.colors import LinearSegmentedColormap

# Assuming athlete_events is a DataFrame containing the data
# east_asian_countries list contains the East Asian countries
east_asian_countries = ["China", "Japan", "South Korea", "North Korea", "Taiwan", "Hong Kong", "Mongolia", "Macau",
                        "Vietnam", "Laos", "Cambodia", "Thailand", "Myanmar", "Malaysia", "Singapore", "Brunei",
                        "Philippines", "Indonesia", "Timor-Leste"]

# Load the world map
world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter athlete events for East Asian countries between 1990 and 2016
athlete_counts = athlete_events[(athlete_events['Team'].isin(east_asian_countries)) & 
                                 (athlete_events['Year'].between(1990, 2016))]\
                    .groupby('Team')['ID'].nunique().reset_index(name='athlete_count')

# Merge athlete counts with world map
world_map_with_athletes = world_map.merge(athlete_counts, left_on='name', right_on='Team', how='left')

# Filter East Asian countries from the merged DataFrame
east_asian_map_with_athletes = world_map_with_athletes[world_map_with_athletes['name'].isin(east_asian_countries)]

# Define the custom colormap with the specified colors
colors = ['#FFFFFF', '#00CCFF', '#0099FF', '#0066FF', '#0033CC', '#000099']
boundaries = [0, 500, 1000, 1500, 2000, 2500]
cmap = LinearSegmentedColormap.from_list('custom', colors, N=2500)

# Plot the map with the custom colormap
fig, ax = plt.subplots(figsize=(10, 10))
east_asian_map_with_athletes.plot(ax=ax, column='athlete_count', cmap=cmap, legend=True,
                                  legend_kwds={'label': 'Number of Athletes', 'orientation': 'horizontal'},
                                  edgecolor='black', linewidth=0.5,  # Adding borders to countries
                                  vmin=0, vmax=2500)
ax.set_title('Number of Athletes in East Asian Countries (1990 - 2016)', fontsize=14)
ax.set_axis_off()

# Add country names as annotations in red color
for idx, row in east_asian_map_with_athletes.iterrows():
    ax.annotate(text=row['name'], xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                fontsize=8, ha='center', color='red')

# Add contextily basemap
ctx.add_basemap(ax, crs=east_asian_map_with_athletes.crs.to_string(), source=ctx.providers.Stamen.TonerLite)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23860\4278182363.py:13: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xyzservices\lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 46
# ...
